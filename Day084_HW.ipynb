# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %% [markdown]
# ### Dopout mlp

# %%
from keras.layers import Dropout

def build_mlp_dr(input_shape, output_units=10, num_neurons=[512, 256, 128, 64], drp_ratio=0.4):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %% [markdown]
# ### Regularizers L1 mlp

# %%
from keras.regularizers import l1, l2, l1_l2

def build_mlp_regu(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_ratio=1e-4):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1), 
                                   kernel_regularizer=l1(l1_ratio))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),
                                   kernel_regularizer=l1(l1_ratio))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %% [markdown]
# ### Batch-normalization mlp

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp_batch(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            #x = BatchNormalization()(x)
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
L1_EXP = [1e-2, 1e-4, 1e-8]
Dropout_EXP = 0.25

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp_dr(input_shape=x_train.shape[1:], drp_ratio=Dropout_EXP)
model.summary()
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE, epsilon=None, decay=0.0)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.1400 - accuracy: 0.1954 - val_loss: 1.9650 - val_accuracy: 0.2907
# Epoch 2/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.9560 - accuracy: 0.2791 - val_loss: 1.8135 - val_accuracy: 0.3489
# Epoch 3/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.8891 - accuracy: 0.3108 - val_loss: 1.8072 - val_accuracy: 0.3530
# Epoch 4/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.8618 - accuracy: 0.3222 - val_loss: 1.8001 - val_accuracy: 0.3584ccuracy: 0.
# Epoch 5/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.8339 - accuracy: 0.3327 - val_loss: 1.7645 - val_accuracy: 0.3736
# Epoch 6/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.8111 - accuracy: 0.3393 - val_loss: 1.7351 - val_accuracy: 0.3846
# Epoch 7/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.7960 - accuracy: 0.3502 - val_loss: 1.7515 - val_accuracy: 0.3791
# Epoch 8/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.7763 - accuracy: 0.3618 - val_loss: 1.7118 - val_accuracy: 0.3896
# Epoch 9/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.7612 - accuracy: 0.3636 - val_loss: 1.6730 - val_accuracy: 0.4027
# Epoch 10/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.7591 - accuracy: 0.3660 - val_loss: 1.7055 - val_accuracy: 0.3995
# Epoch 11/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.7456 - accuracy: 0.3717 - val_loss: 1.6586 - val_accuracy: 0.4214
# Epoch 12/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.7320 - accuracy: 0.3773 - val_loss: 1.6396 - val_accuracy: 0.4296
# Epoch 13/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.7110 - accuracy: 0.3859 - val_loss: 1.6553 - val_accuracy: 0.4180
# Epoch 14/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.7126 - accuracy: 0.3846 - val_loss: 1.6362 - val_accuracy: 0.4198
# Epoch 15/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.7008 - accuracy: 0.3883 - val_loss: 1.6069 - val_accuracy: 0.4375
# Epoch 16/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.7052 - accuracy: 0.3879 - val_loss: 1.6136 - val_accuracy: 0.4323
# Epoch 17/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6866 - accuracy: 0.3944 - val_loss: 1.6045 - val_accuracy: 0.4414
# Epoch 18/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6794 - accuracy: 0.3959 - val_loss: 1.6030 - val_accuracy: 0.4381
# Epoch 19/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6779 - accuracy: 0.3979 - val_loss: 1.6147 - val_accuracy: 0.4281
# Epoch 20/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6701 - accuracy: 0.4003 - val_loss: 1.5906 - val_accuracy: 0.4351
# Epoch 21/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6647 - accuracy: 0.4036 - val_loss: 1.5732 - val_accuracy: 0.4451
# Epoch 22/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.6540 - accuracy: 0.4086 - val_loss: 1.5710 - val_accuracy: 0.4404
# Epoch 23/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6596 - accuracy: 0.4043 - val_loss: 1.5817 - val_accuracy: 0.4447
# Epoch 24/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6572 - accuracy: 0.4048 - val_loss: 1.5794 - val_accuracy: 0.4419
# Epoch 25/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6437 - accuracy: 0.4114 - val_loss: 1.5571 - val_accuracy: 0.4528
# Epoch 26/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6467 - accuracy: 0.4085 - val_loss: 1.6054 - val_accuracy: 0.4292
# Epoch 27/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6381 - accuracy: 0.4129 - val_loss: 1.5624 - val_accuracy: 0.4495
# Epoch 28/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6385 - accuracy: 0.4161 - val_loss: 1.5557 - val_accuracy: 0.4480
# Epoch 29/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6354 - accuracy: 0.4133 - val_loss: 1.5661 - val_accuracy: 0.4495
# Epoch 30/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6249 - accuracy: 0.4176 - val_loss: 1.5447 - val_accuracy: 0.4532
# Epoch 31/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6276 - accuracy: 0.4182 - val_loss: 1.5630 - val_accuracy: 0.4512
# Epoch 32/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6233 - accuracy: 0.4185 - val_loss: 1.5423 - val_accuracy: 0.4572
# Epoch 33/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6215 - accuracy: 0.4175 - val_loss: 1.5484 - val_accuracy: 0.4528
# Epoch 34/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6179 - accuracy: 0.4183 - val_loss: 1.5576 - val_accuracy: 0.4542
# Epoch 35/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6232 - accuracy: 0.4199 - val_loss: 1.5350 - val_accuracy: 0.4576
# Epoch 36/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6116 - accuracy: 0.4232 - val_loss: 1.5501 - val_accuracy: 0.4543
# Epoch 37/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.6066 - accuracy: 0.4242 - val_loss: 1.5314 - val_accuracy: 0.4592
# Epoch 38/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6044 - accuracy: 0.4233 - val_loss: 1.5359 - val_accuracy: 0.4589
# Epoch 39/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6051 - accuracy: 0.4241 - val_loss: 1.5458 - val_accuracy: 0.4549
# Epoch 40/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.5966 - accuracy: 0.4287 - val_loss: 1.5358 - val_accuracy: 0.4512
# Epoch 41/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6080 - accuracy: 0.4247 - val_loss: 1.5376 - val_accuracy: 0.4563
# Epoch 42/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.5963 - accuracy: 0.4265 - val_loss: 1.5215 - val_accuracy: 0.4611
# Epoch 43/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.5945 - accuracy: 0.4292 - val_loss: 1.5618 - val_accuracy: 0.4425
# Epoch 44/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.5935 - accuracy: 0.4292 - val_loss: 1.5616 - val_accuracy: 0.4376
# Epoch 45/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.5929 - accuracy: 0.4291 - val_loss: 1.5217 - val_accuracy: 0.4678
# Epoch 46/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.5845 - accuracy: 0.4349 - val_loss: 1.5443 - val_accuracy: 0.4630
# Epoch 47/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.5826 - accuracy: 0.4343 - val_loss: 1.5255 - val_accuracy: 0.4599
# Epoch 48/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.5862 - accuracy: 0.4326 - val_loss: 1.5362 - val_accuracy: 0.4585
# Epoch 49/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.5826 - accuracy: 0.4336 - val_loss: 1.5341 - val_accuracy: 0.4599
# Epoch 50/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.5759 - accuracy: 0.4348 - val_loss: 1.5214 - val_accuracy: 0.4603

# %% [markdown]
# ### Dropout figure

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
for regulizer_ratio in L1_EXP:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with Regulizer = %.6f" % (regulizer_ratio))
    model = build_mlp_regu(input_shape=x_train.shape[1:], l1_ratio=regulizer_ratio)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-l1-%s" % str(regulizer_ratio)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with Regulizer = 0.010000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 4s 19ms/step - loss: 198.5674 - accuracy: 0.2356 - val_loss: 41.0152 - val_accuracy: 0.2651
# Epoch 2/50
# 196/196 [==============================] - 4s 18ms/step - loss: 19.0341 - accuracy: 0.1161 - val_loss: 7.2275 - val_accuracy: 0.1000
# Epoch 3/50
# 196/196 [==============================] - 4s 18ms/step - loss: 4.0823 - accuracy: 0.0995 - val_loss: 2.6445 - val_accuracy: 0.1000
# Epoch 4/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.4855 - accuracy: 0.0978 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 5/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0979 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 6/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0986 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 7/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0983 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 8/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0974 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 9/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0961 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 10/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0988 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 11/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0983 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 12/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0979 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 13/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0989 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 14/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0961 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 15/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0992 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 16/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0982 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 17/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0977 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 18/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0975 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 19/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0970 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 20/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0985 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 21/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0962 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 22/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0976 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 23/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.4626 - accuracy: 0.0984 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 24/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0966 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 25/50
# 196/196 [==============================] - 4s 20ms/step - loss: 2.4626 - accuracy: 0.0969 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 26/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.4626 - accuracy: 0.0987 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 27/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.4626 - accuracy: 0.0979 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 28/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0983 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 29/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.4626 - accuracy: 0.0971 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 30/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0977 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 31/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0973 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 32/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0966 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 33/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0981 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 34/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0982 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 35/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0967 - val_loss: 2.4627 - val_accuracy: 0.1000
# Epoch 36/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0975 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 37/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0989 - val_loss: 2.4627 - val_accuracy: 0.1000
# Epoch 38/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0977 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 39/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0980 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 40/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0981 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 41/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0978 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 42/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0984 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 43/50
# 196/196 [==============================] - 3s 18ms/step - loss: 2.4626 - accuracy: 0.0974 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 44/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0982 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 45/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0966 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 46/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0995 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 47/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0971 - val_loss: 2.4627 - val_accuracy: 0.1000
# Epoch 48/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0989 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 49/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0964 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 50/50
# 196/196 [==============================] - 3s 17ms/step - loss: 2.4626 - accuracy: 0.0980 - val_loss: 2.4625 - val_accuracy: 0.1000
# Experiment with Regulizer = 0.000100
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 4s 20ms/step - loss: 6.0055 - accuracy: 0.2717 - val_loss: 5.8090 - val_accuracy: 0.3436
# Epoch 2/50
# 196/196 [==============================] - 4s 18ms/step - loss: 5.7103 - accuracy: 0.3688 - val_loss: 5.6299 - val_accuracy: 0.3888
# Epoch 3/50
# 196/196 [==============================] - 4s 19ms/step - loss: 5.5640 - accuracy: 0.3967 - val_loss: 5.5054 - val_accuracy: 0.4087
# Epoch 4/50
# 196/196 [==============================] - 4s 20ms/step - loss: 5.4417 - accuracy: 0.4184 - val_loss: 5.3930 - val_accuracy: 0.4263
# Epoch 5/50
# 196/196 [==============================] - 4s 21ms/step - loss: 5.3323 - accuracy: 0.4341 - val_loss: 5.2835 - val_accuracy: 0.4395
# Epoch 6/50
# 196/196 [==============================] - 4s 20ms/step - loss: 5.2312 - accuracy: 0.4462 - val_loss: 5.2150 - val_accuracy: 0.4393
# Epoch 7/50
# 196/196 [==============================] - 4s 19ms/step - loss: 5.1376 - accuracy: 0.4584 - val_loss: 5.1151 - val_accuracy: 0.4520
# Epoch 8/50
# 196/196 [==============================] - 4s 19ms/step - loss: 5.0466 - accuracy: 0.4688 - val_loss: 5.0297 - val_accuracy: 0.4551
# Epoch 9/50
# 196/196 [==============================] - 4s 20ms/step - loss: 4.9571 - accuracy: 0.4788 - val_loss: 4.9400 - val_accuracy: 0.4691
# Epoch 10/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.8728 - accuracy: 0.4870 - val_loss: 4.8653 - val_accuracy: 0.4712
# Epoch 11/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.7906 - accuracy: 0.4960 - val_loss: 4.7981 - val_accuracy: 0.4765
# Epoch 12/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.7133 - accuracy: 0.4997 - val_loss: 4.7537 - val_accuracy: 0.4766
# Epoch 13/50
# 196/196 [==============================] - 4s 20ms/step - loss: 4.6350 - accuracy: 0.5057 - val_loss: 4.6572 - val_accuracy: 0.4815
# Epoch 14/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.5576 - accuracy: 0.5134 - val_loss: 4.5776 - val_accuracy: 0.4926
# Epoch 15/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.4847 - accuracy: 0.5212 - val_loss: 4.5460 - val_accuracy: 0.4804
# Epoch 16/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.4117 - accuracy: 0.5249 - val_loss: 4.4660 - val_accuracy: 0.4934
# Epoch 17/50
# 196/196 [==============================] - 4s 20ms/step - loss: 4.3396 - accuracy: 0.5324 - val_loss: 4.4048 - val_accuracy: 0.4980
# Epoch 18/50
# 196/196 [==============================] - 4s 21ms/step - loss: 4.2722 - accuracy: 0.5378 - val_loss: 4.3166 - val_accuracy: 0.5079
# Epoch 19/50
# 196/196 [==============================] - 4s 21ms/step - loss: 4.2011 - accuracy: 0.5420 - val_loss: 4.2756 - val_accuracy: 0.5031
# Epoch 20/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.1328 - accuracy: 0.5476 - val_loss: 4.2189 - val_accuracy: 0.5037
# Epoch 21/50
# 196/196 [==============================] - 4s 20ms/step - loss: 4.0717 - accuracy: 0.5512 - val_loss: 4.1486 - val_accuracy: 0.5102
# Epoch 22/50
# 196/196 [==============================] - 4s 19ms/step - loss: 4.0044 - accuracy: 0.5581 - val_loss: 4.0867 - val_accuracy: 0.5135
# Epoch 23/50
# 196/196 [==============================] - 4s 20ms/step - loss: 3.9372 - accuracy: 0.5616 - val_loss: 4.0729 - val_accuracy: 0.5032
# Epoch 24/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.8813 - accuracy: 0.5643 - val_loss: 4.0124 - val_accuracy: 0.5081
# Epoch 25/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.8188 - accuracy: 0.5679 - val_loss: 3.9241 - val_accuracy: 0.5153
# Epoch 26/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.7602 - accuracy: 0.5713 - val_loss: 3.8628 - val_accuracy: 0.5286
# Epoch 27/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.7007 - accuracy: 0.5761 - val_loss: 3.8142 - val_accuracy: 0.5227
# Epoch 28/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.6400 - accuracy: 0.5804 - val_loss: 3.8040 - val_accuracy: 0.5112
# Epoch 29/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.5867 - accuracy: 0.5821 - val_loss: 3.7381 - val_accuracy: 0.5207
# Epoch 30/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.5281 - accuracy: 0.5874 - val_loss: 3.7232 - val_accuracy: 0.5038
# Epoch 31/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.4748 - accuracy: 0.5895 - val_loss: 3.7134 - val_accuracy: 0.5004
# Epoch 32/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.4238 - accuracy: 0.5921 - val_loss: 3.5935 - val_accuracy: 0.5221
# Epoch 33/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.3689 - accuracy: 0.5964 - val_loss: 3.5455 - val_accuracy: 0.5182
# Epoch 34/50
# 196/196 [==============================] - 4s 21ms/step - loss: 3.3197 - accuracy: 0.5973 - val_loss: 3.4766 - val_accuracy: 0.5360
# Epoch 35/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.2668 - accuracy: 0.6014 - val_loss: 3.4918 - val_accuracy: 0.5177
# Epoch 36/50
# 196/196 [==============================] - 4s 20ms/step - loss: 3.2182 - accuracy: 0.6032 - val_loss: 3.4197 - val_accuracy: 0.5239
# Epoch 37/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.1728 - accuracy: 0.6062 - val_loss: 3.4901 - val_accuracy: 0.4965
# Epoch 38/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.1228 - accuracy: 0.6104 - val_loss: 3.3974 - val_accuracy: 0.5079
# Epoch 39/50
# 196/196 [==============================] - 4s 20ms/step - loss: 3.0750 - accuracy: 0.6110 - val_loss: 3.3735 - val_accuracy: 0.5034
# Epoch 40/50
# 196/196 [==============================] - 4s 19ms/step - loss: 3.0262 - accuracy: 0.6154 - val_loss: 3.3343 - val_accuracy: 0.5085
# Epoch 41/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.9863 - accuracy: 0.6184 - val_loss: 3.2351 - val_accuracy: 0.5237
# Epoch 42/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.9409 - accuracy: 0.6176 - val_loss: 3.2284 - val_accuracy: 0.5137
# Epoch 43/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.8996 - accuracy: 0.6197 - val_loss: 3.2318 - val_accuracy: 0.5012
# Epoch 44/50
# 196/196 [==============================] - 4s 20ms/step - loss: 2.8557 - accuracy: 0.6228 - val_loss: 3.1562 - val_accuracy: 0.5205
# Epoch 45/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.8215 - accuracy: 0.6244 - val_loss: 3.0644 - val_accuracy: 0.5309
# Epoch 46/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.7770 - accuracy: 0.6274 - val_loss: 3.1415 - val_accuracy: 0.4963
# Epoch 47/50
# 196/196 [==============================] - 4s 19ms/step - loss: 2.7395 - accuracy: 0.6273 - val_loss: 3.0090 - val_accuracy: 0.5241
# Epoch 48/50
# 196/196 [==============================] - 4s 21ms/step - loss: 2.7042 - accuracy: 0.6282 - val_loss: 2.9535 - val_accuracy: 0.5372
# Epoch 49/50
# 196/196 [==============================] - 4s 21ms/step - loss: 2.6670 - accuracy: 0.6304 - val_loss: 3.1211 - val_accuracy: 0.4761
# Epoch 50/50
# 196/196 [==============================] - 4s 21ms/step - loss: 2.6345 - accuracy: 0.6280 - val_loss: 3.0747 - val_accuracy: 0.4924
# Experiment with Regulizer = 0.000000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 4s 21ms/step - loss: 2.0402 - accuracy: 0.2700 - val_loss: 1.8780 - val_accuracy: 0.3391
# Epoch 2/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.8104 - accuracy: 0.3659 - val_loss: 1.7580 - val_accuracy: 0.3850
# Epoch 3/50
# 196/196 [==============================] - 4s 20ms/step - loss: 1.7223 - accuracy: 0.3994 - val_loss: 1.7138 - val_accuracy: 0.3843
# Epoch 4/50
# 196/196 [==============================] - 4s 21ms/step - loss: 1.6675 - accuracy: 0.4195 - val_loss: 1.6569 - val_accuracy: 0.4137
# Epoch 5/50
# 196/196 [==============================] - 4s 21ms/step - loss: 1.6214 - accuracy: 0.4347 - val_loss: 1.6085 - val_accuracy: 0.4305
# Epoch 6/50
# 196/196 [==============================] - 4s 20ms/step - loss: 1.5815 - accuracy: 0.4485 - val_loss: 1.5796 - val_accuracy: 0.4509
# Epoch 7/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.5477 - accuracy: 0.4563 - val_loss: 1.5499 - val_accuracy: 0.4547
# Epoch 8/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.5180 - accuracy: 0.4695 - val_loss: 1.5213 - val_accuracy: 0.4699
# Epoch 9/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.4888 - accuracy: 0.4772 - val_loss: 1.5103 - val_accuracy: 0.4603
# Epoch 10/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.4652 - accuracy: 0.4880 - val_loss: 1.4914 - val_accuracy: 0.4765
# Epoch 11/50
# 196/196 [==============================] - 4s 20ms/step - loss: 1.4413 - accuracy: 0.4968 - val_loss: 1.4684 - val_accuracy: 0.4838
# Epoch 12/50
# 196/196 [==============================] - 4s 20ms/step - loss: 1.4171 - accuracy: 0.5058 - val_loss: 1.5308 - val_accuracy: 0.4532
# Epoch 13/50
# 196/196 [==============================] - 4s 20ms/step - loss: 1.3982 - accuracy: 0.5094 - val_loss: 1.4643 - val_accuracy: 0.4840
# Epoch 14/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.3781 - accuracy: 0.5166 - val_loss: 1.4438 - val_accuracy: 0.4887
# Epoch 15/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.3582 - accuracy: 0.5223 - val_loss: 1.4275 - val_accuracy: 0.4948
# Epoch 16/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.3399 - accuracy: 0.5297 - val_loss: 1.4054 - val_accuracy: 0.4979
# Epoch 17/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.3236 - accuracy: 0.5355 - val_loss: 1.4291 - val_accuracy: 0.4905
# Epoch 18/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.3060 - accuracy: 0.5412 - val_loss: 1.4204 - val_accuracy: 0.4953
# Epoch 19/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.2904 - accuracy: 0.5458 - val_loss: 1.3886 - val_accuracy: 0.5070
# Epoch 20/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2716 - accuracy: 0.5523 - val_loss: 1.3844 - val_accuracy: 0.5083
# Epoch 21/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.2578 - accuracy: 0.5576 - val_loss: 1.3828 - val_accuracy: 0.5087
# Epoch 22/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.2441 - accuracy: 0.5627 - val_loss: 1.3948 - val_accuracy: 0.5091
# Epoch 23/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.2284 - accuracy: 0.5678 - val_loss: 1.3827 - val_accuracy: 0.5098
# Epoch 24/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.2154 - accuracy: 0.5730 - val_loss: 1.3686 - val_accuracy: 0.5135
# Epoch 25/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.2012 - accuracy: 0.5783 - val_loss: 1.3974 - val_accuracy: 0.5072
# Epoch 26/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.1871 - accuracy: 0.5809 - val_loss: 1.3688 - val_accuracy: 0.5114
# Epoch 27/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1721 - accuracy: 0.5881 - val_loss: 1.3608 - val_accuracy: 0.5172
# Epoch 28/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.1607 - accuracy: 0.5935 - val_loss: 1.3709 - val_accuracy: 0.5155
# Epoch 29/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1482 - accuracy: 0.5964 - val_loss: 1.3727 - val_accuracy: 0.5199
# Epoch 30/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1336 - accuracy: 0.6019 - val_loss: 1.4259 - val_accuracy: 0.4998
# Epoch 31/50
# 196/196 [==============================] - 4s 22ms/step - loss: 1.1211 - accuracy: 0.6047 - val_loss: 1.3745 - val_accuracy: 0.5138
# Epoch 32/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.1051 - accuracy: 0.6129 - val_loss: 1.3363 - val_accuracy: 0.5336
# Epoch 33/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0913 - accuracy: 0.6177 - val_loss: 1.3432 - val_accuracy: 0.5292
# Epoch 34/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.0793 - accuracy: 0.6197 - val_loss: 1.3820 - val_accuracy: 0.5141
# Epoch 35/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0657 - accuracy: 0.6279 - val_loss: 1.3976 - val_accuracy: 0.5126
# Epoch 36/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0555 - accuracy: 0.6280 - val_loss: 1.3270 - val_accuracy: 0.5310
# Epoch 37/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0390 - accuracy: 0.6342 - val_loss: 1.3532 - val_accuracy: 0.5276
# Epoch 38/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.0256 - accuracy: 0.6405 - val_loss: 1.3637 - val_accuracy: 0.5272
# Epoch 39/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.0154 - accuracy: 0.6451 - val_loss: 1.3741 - val_accuracy: 0.5231
# Epoch 40/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0050 - accuracy: 0.6476 - val_loss: 1.3714 - val_accuracy: 0.5263
# Epoch 41/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9895 - accuracy: 0.6540 - val_loss: 1.3800 - val_accuracy: 0.5199
# Epoch 42/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9755 - accuracy: 0.6565 - val_loss: 1.3741 - val_accuracy: 0.5203
# Epoch 43/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9637 - accuracy: 0.6605 - val_loss: 1.4439 - val_accuracy: 0.5067
# Epoch 44/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9554 - accuracy: 0.6650 - val_loss: 1.4714 - val_accuracy: 0.4959
# Epoch 45/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9432 - accuracy: 0.6692 - val_loss: 1.5513 - val_accuracy: 0.4884
# Epoch 46/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9262 - accuracy: 0.6757 - val_loss: 1.4070 - val_accuracy: 0.5272
# Epoch 47/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9157 - accuracy: 0.6779 - val_loss: 1.3711 - val_accuracy: 0.5290
# Epoch 48/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9040 - accuracy: 0.6818 - val_loss: 1.4007 - val_accuracy: 0.5207
# Epoch 49/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8915 - accuracy: 0.6872 - val_loss: 1.4107 - val_accuracy: 0.5263
# Epoch 50/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8787 - accuracy: 0.6928 - val_loss: 1.4318 - val_accuracy: 0.5203

# %% [markdown]
# ### Regularizers figure

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
model = build_mlp_batch(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.8631 - accuracy: 0.3596 - val_loss: 1.7930 - val_accuracy: 0.3661
# Epoch 2/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.5412 - accuracy: 0.4570 - val_loss: 1.5810 - val_accuracy: 0.4405
# Epoch 3/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.4314 - accuracy: 0.4948 - val_loss: 1.6131 - val_accuracy: 0.4355
# Epoch 4/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.3621 - accuracy: 0.5215 - val_loss: 1.5569 - val_accuracy: 0.4382
# Epoch 5/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.2997 - accuracy: 0.5431 - val_loss: 1.5337 - val_accuracy: 0.4691
# Epoch 6/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.2472 - accuracy: 0.5640 - val_loss: 1.4842 - val_accuracy: 0.4792
# Epoch 7/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.2011 - accuracy: 0.5807 - val_loss: 1.5137 - val_accuracy: 0.4616
# Epoch 8/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1549 - accuracy: 0.5959 - val_loss: 1.4691 - val_accuracy: 0.4834
# Epoch 9/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1135 - accuracy: 0.6127 - val_loss: 1.5591 - val_accuracy: 0.4631
# Epoch 10/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0777 - accuracy: 0.6226 - val_loss: 1.4956 - val_accuracy: 0.4879
# Epoch 11/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0414 - accuracy: 0.6401 - val_loss: 1.4984 - val_accuracy: 0.4821
# Epoch 12/50
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0059 - accuracy: 0.6503 - val_loss: 1.6137 - val_accuracy: 0.4683
# Epoch 13/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.9708 - accuracy: 0.6630 - val_loss: 1.5146 - val_accuracy: 0.4813
# Epoch 14/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.9389 - accuracy: 0.6750 - val_loss: 1.6662 - val_accuracy: 0.4503
# Epoch 15/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.9004 - accuracy: 0.6917 - val_loss: 1.5947 - val_accuracy: 0.4699
# Epoch 16/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.8687 - accuracy: 0.7008 - val_loss: 1.4917 - val_accuracy: 0.4914
# Epoch 17/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.8379 - accuracy: 0.7116 - val_loss: 1.5498 - val_accuracy: 0.4900
# Epoch 18/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.8069 - accuracy: 0.7268 - val_loss: 1.6577 - val_accuracy: 0.4677
# Epoch 19/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.7747 - accuracy: 0.7373 - val_loss: 1.6203 - val_accuracy: 0.4846
# Epoch 20/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.7415 - accuracy: 0.7481 - val_loss: 1.6529 - val_accuracy: 0.4829
# Epoch 21/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.7124 - accuracy: 0.7603 - val_loss: 1.6658 - val_accuracy: 0.4778
# Epoch 22/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.6862 - accuracy: 0.7691 - val_loss: 1.8901 - val_accuracy: 0.4382
# Epoch 23/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.6533 - accuracy: 0.7812 - val_loss: 1.7224 - val_accuracy: 0.4711
# Epoch 24/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.6282 - accuracy: 0.7908 - val_loss: 1.6934 - val_accuracy: 0.4847
# Epoch 25/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.6022 - accuracy: 0.7993 - val_loss: 1.9280 - val_accuracy: 0.4540
# Epoch 26/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.5717 - accuracy: 0.8101 - val_loss: 1.7784 - val_accuracy: 0.4684
# Epoch 27/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.5444 - accuracy: 0.8206 - val_loss: 1.7898 - val_accuracy: 0.4785
# Epoch 28/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.5185 - accuracy: 0.8310 - val_loss: 1.8780 - val_accuracy: 0.4808
# Epoch 29/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.4983 - accuracy: 0.8375 - val_loss: 1.9626 - val_accuracy: 0.4591
# Epoch 30/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.4718 - accuracy: 0.8476 - val_loss: 1.8767 - val_accuracy: 0.4799
# Epoch 31/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.4501 - accuracy: 0.8539 - val_loss: 1.8946 - val_accuracy: 0.4807
# Epoch 32/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.4232 - accuracy: 0.8646 - val_loss: 2.0048 - val_accuracy: 0.4676
# Epoch 33/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.4079 - accuracy: 0.8714 - val_loss: 2.0401 - val_accuracy: 0.4657
# Epoch 34/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3877 - accuracy: 0.8787 - val_loss: 1.9347 - val_accuracy: 0.4714
# Epoch 35/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3676 - accuracy: 0.8839 - val_loss: 2.0383 - val_accuracy: 0.4697
# Epoch 36/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3480 - accuracy: 0.8919 - val_loss: 2.1222 - val_accuracy: 0.4587
# Epoch 37/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3298 - accuracy: 0.8998 - val_loss: 2.2168 - val_accuracy: 0.4527
# Epoch 38/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3154 - accuracy: 0.9046 - val_loss: 2.4301 - val_accuracy: 0.4475
# Epoch 39/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2980 - accuracy: 0.9095 - val_loss: 2.2159 - val_accuracy: 0.4764
# Epoch 40/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2750 - accuracy: 0.9183 - val_loss: 2.1322 - val_accuracy: 0.4753
# Epoch 41/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2695 - accuracy: 0.9203 - val_loss: 2.2232 - val_accuracy: 0.4646
# Epoch 42/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2546 - accuracy: 0.9251 - val_loss: 2.2375 - val_accuracy: 0.4705
# Epoch 43/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2414 - accuracy: 0.9290 - val_loss: 2.2539 - val_accuracy: 0.4724
# Epoch 44/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2242 - accuracy: 0.9362 - val_loss: 2.2792 - val_accuracy: 0.4790
# Epoch 45/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2096 - accuracy: 0.9412 - val_loss: 2.4724 - val_accuracy: 0.4660
# Epoch 46/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2016 - accuracy: 0.9451 - val_loss: 2.3024 - val_accuracy: 0.4722
# Epoch 47/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.1881 - accuracy: 0.9486 - val_loss: 2.3309 - val_accuracy: 0.4799
# Epoch 48/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.1806 - accuracy: 0.9512 - val_loss: 2.5773 - val_accuracy: 0.4656
# Epoch 49/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.1675 - accuracy: 0.9562 - val_loss: 2.5079 - val_accuracy: 0.4723
# Epoch 50/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.1682 - accuracy: 0.9540 - val_loss: 2.4646 - val_accuracy: 0.4634

# %% [markdown]
# ### Batch-normalization figure

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
Batch-normalization figure

# %% [markdown]
# ## Work
# 1. 請比較使用 l1, l1_l2 及不同比例下的訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1, l2, l1_l2

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_ratio=1e-4):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1), 
                                   kernel_regularizer=l1(l1_ratio))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),
                                   kernel_regularizer=l1(l1_ratio))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
L1_EXP = [1e-2, 1e-4, 1e-8]
l1_l2_EXP = [1e-2, 1e-4, 1e-8]

# %%
l1
# Out:
# tensorflow.python.keras.regularizers.L1

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for regulizer_ratio in L1_EXP:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with Regulizer = %.6f" % (regulizer_ratio))
    model = build_mlp(input_shape=x_train.shape[1:], l1_ratio=regulizer_ratio)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-l1-%s" % str(regulizer_ratio)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with Regulizer = 0.010000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 6s 29ms/step - loss: 198.7089 - accuracy: 0.2446 - val_loss: 41.1151 - val_accuracy: 0.2577
# Epoch 2/50
# 196/196 [==============================] - 5s 28ms/step - loss: 19.1082 - accuracy: 0.1169 - val_loss: 7.2944 - val_accuracy: 0.1000
# Epoch 3/50
# 196/196 [==============================] - 5s 26ms/step - loss: 4.1158 - accuracy: 0.0993 - val_loss: 2.6521 - val_accuracy: 0.1000
# Epoch 4/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4870 - accuracy: 0.0988 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 5/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0985 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 6/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0982 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 7/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0969 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 8/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0982 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 9/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0967 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 10/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0978 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 11/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0989 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 12/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.1001 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 13/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0987 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 14/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0977 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 15/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0982 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 16/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0969 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 17/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0981 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 18/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0985 - val_loss: 2.4627 - val_accuracy: 0.1000
# Epoch 19/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0981 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 20/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0978 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 21/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0993 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 22/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0984 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 23/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0968 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 24/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0974 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 25/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0964 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 26/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0969 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 27/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0965 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 28/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0990 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 29/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0971 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 30/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0992 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 31/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0984 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 32/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0964 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 33/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0981 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 34/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0988 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 35/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0952 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 36/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0975 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 37/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0978 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 38/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0993 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 39/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0988 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 40/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0974 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 41/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0987 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 42/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0967 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 43/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0983 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 44/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0980 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 45/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0984 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 46/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0971 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 47/50
# 196/196 [==============================] - 5s 27ms/step - loss: 2.4626 - accuracy: 0.0976 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 48/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0985 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 49/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.4626 - accuracy: 0.0978 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 50/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.4626 - accuracy: 0.0997 - val_loss: 2.4625 - val_accuracy: 0.1000
# Experiment with Regulizer = 0.000100
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 5s 26ms/step - loss: 5.9935 - accuracy: 0.2780 - val_loss: 5.8040 - val_accuracy: 0.3397
# Epoch 2/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.7111 - accuracy: 0.3704 - val_loss: 5.6313 - val_accuracy: 0.3839
# Epoch 3/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.5680 - accuracy: 0.3966 - val_loss: 5.5043 - val_accuracy: 0.4072
# Epoch 4/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.4500 - accuracy: 0.4178 - val_loss: 5.4033 - val_accuracy: 0.4258
# Epoch 5/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.3425 - accuracy: 0.4330 - val_loss: 5.2976 - val_accuracy: 0.4348
# Epoch 6/50
# 196/196 [==============================] - 5s 24ms/step - loss: 5.2428 - accuracy: 0.4449 - val_loss: 5.2145 - val_accuracy: 0.4432
# Epoch 7/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.1486 - accuracy: 0.4567 - val_loss: 5.1215 - val_accuracy: 0.4504
# Epoch 8/50
# 196/196 [==============================] - 5s 25ms/step - loss: 5.0587 - accuracy: 0.4671 - val_loss: 5.0358 - val_accuracy: 0.4579
# Epoch 9/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.9725 - accuracy: 0.4744 - val_loss: 4.9594 - val_accuracy: 0.4621
# Epoch 10/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.8893 - accuracy: 0.4819 - val_loss: 4.8730 - val_accuracy: 0.4695
# Epoch 11/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.8089 - accuracy: 0.4886 - val_loss: 4.8215 - val_accuracy: 0.4705
# Epoch 12/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.7299 - accuracy: 0.4954 - val_loss: 4.7290 - val_accuracy: 0.4760
# Epoch 13/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.6524 - accuracy: 0.5027 - val_loss: 4.6650 - val_accuracy: 0.4811
# Epoch 14/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.5767 - accuracy: 0.5073 - val_loss: 4.5902 - val_accuracy: 0.4923
# Epoch 15/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.5025 - accuracy: 0.5136 - val_loss: 4.5314 - val_accuracy: 0.4868
# Epoch 16/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.4305 - accuracy: 0.5200 - val_loss: 4.4669 - val_accuracy: 0.4920
# Epoch 17/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.3592 - accuracy: 0.5260 - val_loss: 4.4002 - val_accuracy: 0.5002
# Epoch 18/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.2904 - accuracy: 0.5310 - val_loss: 4.3722 - val_accuracy: 0.4819
# Epoch 19/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.2222 - accuracy: 0.5349 - val_loss: 4.3107 - val_accuracy: 0.4952
# Epoch 20/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.1574 - accuracy: 0.5403 - val_loss: 4.2602 - val_accuracy: 0.4911
# Epoch 21/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.0894 - accuracy: 0.5460 - val_loss: 4.1526 - val_accuracy: 0.5082
# Epoch 22/50
# 196/196 [==============================] - 5s 25ms/step - loss: 4.0263 - accuracy: 0.5514 - val_loss: 4.0868 - val_accuracy: 0.5143
# Epoch 23/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.9602 - accuracy: 0.5540 - val_loss: 4.0514 - val_accuracy: 0.5045
# Epoch 24/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.8986 - accuracy: 0.5587 - val_loss: 3.9773 - val_accuracy: 0.5159
# Epoch 25/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.8386 - accuracy: 0.5621 - val_loss: 4.0039 - val_accuracy: 0.4926
# Epoch 26/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.7759 - accuracy: 0.5653 - val_loss: 3.8966 - val_accuracy: 0.5024
# Epoch 27/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.7198 - accuracy: 0.5702 - val_loss: 3.8115 - val_accuracy: 0.5284
# Epoch 28/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.6586 - accuracy: 0.5751 - val_loss: 3.8524 - val_accuracy: 0.4922
# Epoch 29/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.6061 - accuracy: 0.5748 - val_loss: 3.7482 - val_accuracy: 0.5134
# Epoch 30/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.5490 - accuracy: 0.5804 - val_loss: 3.6934 - val_accuracy: 0.5100
# Epoch 31/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.4956 - accuracy: 0.5834 - val_loss: 3.6357 - val_accuracy: 0.5257
# Epoch 32/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.4395 - accuracy: 0.5844 - val_loss: 3.5877 - val_accuracy: 0.5247
# Epoch 33/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.3824 - accuracy: 0.5921 - val_loss: 3.5705 - val_accuracy: 0.5085
# Epoch 34/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.3351 - accuracy: 0.5908 - val_loss: 3.5598 - val_accuracy: 0.5077
# Epoch 35/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.2821 - accuracy: 0.5940 - val_loss: 3.4203 - val_accuracy: 0.5406
# Epoch 36/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.2338 - accuracy: 0.5977 - val_loss: 3.4454 - val_accuracy: 0.5226
# Epoch 37/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.1882 - accuracy: 0.6006 - val_loss: 3.3509 - val_accuracy: 0.5314
# Epoch 38/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.1335 - accuracy: 0.6043 - val_loss: 3.3593 - val_accuracy: 0.5163
# Epoch 39/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.0886 - accuracy: 0.6062 - val_loss: 3.3660 - val_accuracy: 0.5013
# Epoch 40/50
# 196/196 [==============================] - 5s 25ms/step - loss: 3.0447 - accuracy: 0.6076 - val_loss: 3.2439 - val_accuracy: 0.5303
# Epoch 41/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.9958 - accuracy: 0.6102 - val_loss: 3.1807 - val_accuracy: 0.5358
# Epoch 42/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.9529 - accuracy: 0.6155 - val_loss: 3.1677 - val_accuracy: 0.5274
# Epoch 43/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.9102 - accuracy: 0.6168 - val_loss: 3.1087 - val_accuracy: 0.5367
# Epoch 44/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.8710 - accuracy: 0.6177 - val_loss: 3.1879 - val_accuracy: 0.5063
# Epoch 45/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.8315 - accuracy: 0.6184 - val_loss: 3.0708 - val_accuracy: 0.5330
# Epoch 46/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.7897 - accuracy: 0.6226 - val_loss: 3.1186 - val_accuracy: 0.5076
# Epoch 47/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.7475 - accuracy: 0.6231 - val_loss: 3.0586 - val_accuracy: 0.5140
# Epoch 48/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.7117 - accuracy: 0.6251 - val_loss: 2.9632 - val_accuracy: 0.5293
# Epoch 49/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.6740 - accuracy: 0.6280 - val_loss: 2.9483 - val_accuracy: 0.5274
# Epoch 50/50
# 196/196 [==============================] - 5s 25ms/step - loss: 2.6409 - accuracy: 0.6255 - val_loss: 2.9358 - val_accuracy: 0.5168
# Experiment with Regulizer = 0.000000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 5s 26ms/step - loss: 2.0366 - accuracy: 0.2683 - val_loss: 1.8812 - val_accuracy: 0.3338
# Epoch 2/50
# 196/196 [==============================] - 5s 24ms/step - loss: 1.8165 - accuracy: 0.3591 - val_loss: 1.7784 - val_accuracy: 0.3788
# Epoch 3/50
# 196/196 [==============================] - 5s 24ms/step - loss: 1.7285 - accuracy: 0.3930 - val_loss: 1.6949 - val_accuracy: 0.4081
# Epoch 4/50
# 196/196 [==============================] - 5s 24ms/step - loss: 1.6669 - accuracy: 0.4163 - val_loss: 1.6502 - val_accuracy: 0.4184
# Epoch 5/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.6183 - accuracy: 0.4336 - val_loss: 1.6003 - val_accuracy: 0.4382
# Epoch 6/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.5758 - accuracy: 0.4492 - val_loss: 1.5752 - val_accuracy: 0.4457
# Epoch 7/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.5403 - accuracy: 0.4611 - val_loss: 1.5465 - val_accuracy: 0.4493
# Epoch 8/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.5109 - accuracy: 0.4695 - val_loss: 1.5346 - val_accuracy: 0.4557
# Epoch 9/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.4833 - accuracy: 0.4805 - val_loss: 1.5231 - val_accuracy: 0.4598
# Epoch 10/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.4547 - accuracy: 0.4899 - val_loss: 1.5162 - val_accuracy: 0.4624
# Epoch 11/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.4330 - accuracy: 0.4984 - val_loss: 1.4823 - val_accuracy: 0.4729
# Epoch 12/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.4086 - accuracy: 0.5056 - val_loss: 1.4478 - val_accuracy: 0.4865
# Epoch 13/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.3867 - accuracy: 0.5121 - val_loss: 1.4415 - val_accuracy: 0.4833
# Epoch 14/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.3679 - accuracy: 0.5210 - val_loss: 1.4187 - val_accuracy: 0.4991
# Epoch 15/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.3492 - accuracy: 0.5255 - val_loss: 1.4237 - val_accuracy: 0.4939
# Epoch 16/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.3306 - accuracy: 0.5339 - val_loss: 1.4100 - val_accuracy: 0.5011
# Epoch 17/50
# 196/196 [==============================] - 5s 27ms/step - loss: 1.3148 - accuracy: 0.5400 - val_loss: 1.4063 - val_accuracy: 0.5017
# Epoch 18/50
# 196/196 [==============================] - 6s 29ms/step - loss: 1.2947 - accuracy: 0.5480 - val_loss: 1.3805 - val_accuracy: 0.5102
# Epoch 19/50
# 196/196 [==============================] - 5s 27ms/step - loss: 1.2796 - accuracy: 0.5509 - val_loss: 1.3830 - val_accuracy: 0.5094
# Epoch 20/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.2627 - accuracy: 0.5571 - val_loss: 1.4079 - val_accuracy: 0.5050
# Epoch 21/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.2508 - accuracy: 0.5628 - val_loss: 1.3801 - val_accuracy: 0.5074
# Epoch 22/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.2334 - accuracy: 0.5685 - val_loss: 1.3720 - val_accuracy: 0.5168
# Epoch 23/50
# 196/196 [==============================] - 5s 25ms/step - loss: 1.2174 - accuracy: 0.5740 - val_loss: 1.3517 - val_accuracy: 0.5196
# Epoch 24/50
# 196/196 [==============================] - 5s 24ms/step - loss: 1.2050 - accuracy: 0.5778 - val_loss: 1.3839 - val_accuracy: 0.5092
# Epoch 25/50
# 196/196 [==============================] - 5s 24ms/step - loss: 1.1902 - accuracy: 0.5826 - val_loss: 1.3534 - val_accuracy: 0.5204
# Epoch 26/50
# 196/196 [==============================] - 5s 24ms/step - loss: 1.1751 - accuracy: 0.5881 - val_loss: 1.3448 - val_accuracy: 0.5281
# Epoch 27/50
# 196/196 [==============================] - 5s 23ms/step - loss: 1.1609 - accuracy: 0.5928 - val_loss: 1.4794 - val_accuracy: 0.4806
# Epoch 28/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.1504 - accuracy: 0.5978 - val_loss: 1.3421 - val_accuracy: 0.5242
# Epoch 29/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1345 - accuracy: 0.6010 - val_loss: 1.3899 - val_accuracy: 0.5091
# Epoch 30/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.1196 - accuracy: 0.6069 - val_loss: 1.3400 - val_accuracy: 0.5293
# Epoch 31/50
# 196/196 [==============================] - 3s 17ms/step - loss: 1.1077 - accuracy: 0.6107 - val_loss: 1.3450 - val_accuracy: 0.5259
# Epoch 32/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.0949 - accuracy: 0.6177 - val_loss: 1.3773 - val_accuracy: 0.5180
# Epoch 33/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0822 - accuracy: 0.6209 - val_loss: 1.3690 - val_accuracy: 0.5237
# Epoch 34/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.0719 - accuracy: 0.6236 - val_loss: 1.3540 - val_accuracy: 0.5264
# Epoch 35/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.0555 - accuracy: 0.6315 - val_loss: 1.3411 - val_accuracy: 0.5260
# Epoch 36/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.0444 - accuracy: 0.6324 - val_loss: 1.3294 - val_accuracy: 0.5296
# Epoch 37/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0358 - accuracy: 0.6369 - val_loss: 1.3467 - val_accuracy: 0.5247
# Epoch 38/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.0191 - accuracy: 0.6431 - val_loss: 1.3407 - val_accuracy: 0.5309
# Epoch 39/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0058 - accuracy: 0.6476 - val_loss: 1.3585 - val_accuracy: 0.5292
# Epoch 40/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9941 - accuracy: 0.6515 - val_loss: 1.3295 - val_accuracy: 0.5381
# Epoch 41/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.9799 - accuracy: 0.6555 - val_loss: 1.4034 - val_accuracy: 0.5200
# Epoch 42/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9691 - accuracy: 0.6616 - val_loss: 1.3314 - val_accuracy: 0.5377
# Epoch 43/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.9573 - accuracy: 0.6650 - val_loss: 1.4939 - val_accuracy: 0.5003
# Epoch 44/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9437 - accuracy: 0.6685 - val_loss: 1.3768 - val_accuracy: 0.5335
# Epoch 45/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.9304 - accuracy: 0.6765 - val_loss: 1.3516 - val_accuracy: 0.5347
# Epoch 46/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9232 - accuracy: 0.6769 - val_loss: 1.4131 - val_accuracy: 0.5244
# Epoch 47/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.9106 - accuracy: 0.6807 - val_loss: 1.3484 - val_accuracy: 0.5393
# Epoch 48/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.8968 - accuracy: 0.6863 - val_loss: 1.4025 - val_accuracy: 0.5277
# Epoch 49/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8835 - accuracy: 0.6905 - val_loss: 1.4170 - val_accuracy: 0.5187
# Epoch 50/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.8700 - accuracy: 0.6951 - val_loss: 1.5203 - val_accuracy: 0.5024

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

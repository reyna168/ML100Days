# %% [markdown]
# # 請結合前面的知識與程式碼，比較不同的 optimizer 與 learning rate 組合對訓練的結果與影響
# ### 常見的 optimizer 包含
# * SGD
# * RMSprop
# * AdaGrad
# * Adam

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your required experiment parameters
"""
LEARNING_RATE = [1,0.1,0.01]
EPOCHS = 20
BATCH_SIZE = 256
MOMENTUM = 0.8

# %% [markdown]
# SGD

# %%
results = {}
"""
建立你的訓練與實驗迴圈並蒐集資料
"""
for lr in LEARNING_RATE:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with LR = %.6f" % (lr))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=lr, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-lr-%s" % str(lr)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with LR = 1.000000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 6s 28ms/step - loss: nan - accuracy: 0.1002 - val_loss: nan - val_accuracy: 0.1000
# Epoch 2/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 3/20
# 196/196 [==============================] - 4s 23ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 4/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 5/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 6/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 7/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 8/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 9/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 10/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 11/20
# 196/196 [==============================] - 5s 26ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 12/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 13/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 14/20
# 196/196 [==============================] - 5s 26ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 15/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 16/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 17/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 18/20
# 196/196 [==============================] - 5s 24ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 19/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Epoch 20/20
# 196/196 [==============================] - 5s 25ms/step - loss: nan - accuracy: 0.1000 - val_loss: nan - val_accuracy: 0.1000
# Experiment with LR = 0.100000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 6s 30ms/step - loss: 1.9972 - accuracy: 0.2687 - val_loss: 1.9147 - val_accuracy: 0.3154
# Epoch 2/20
# 196/196 [==============================] - 5s 26ms/step - loss: 1.7749 - accuracy: 0.3593 - val_loss: 1.7317 - val_accuracy: 0.3696
# Epoch 3/20
# 196/196 [==============================] - 5s 25ms/step - loss: 1.6813 - accuracy: 0.3990 - val_loss: 1.6836 - val_accuracy: 0.3850
# Epoch 4/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.6295 - accuracy: 0.4147 - val_loss: 1.6825 - val_accuracy: 0.3906
# Epoch 5/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.5738 - accuracy: 0.4375 - val_loss: 1.5900 - val_accuracy: 0.4253
# Epoch 6/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.5274 - accuracy: 0.4507 - val_loss: 1.5772 - val_accuracy: 0.4355
# Epoch 7/20
# 196/196 [==============================] - 3s 16ms/step - loss: 1.5067 - accuracy: 0.4600 - val_loss: 1.5782 - val_accuracy: 0.4274
# Epoch 8/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.4774 - accuracy: 0.4713 - val_loss: 1.5316 - val_accuracy: 0.4451
# Epoch 9/20
# 196/196 [==============================] - 4s 22ms/step - loss: 1.4521 - accuracy: 0.4818 - val_loss: 1.4859 - val_accuracy: 0.4771
# Epoch 10/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.4200 - accuracy: 0.4907 - val_loss: 1.5410 - val_accuracy: 0.4577
# Epoch 11/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.3992 - accuracy: 0.4999 - val_loss: 1.5327 - val_accuracy: 0.4587
# Epoch 12/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.3802 - accuracy: 0.5062 - val_loss: 1.5558 - val_accuracy: 0.4441
# Epoch 13/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.3652 - accuracy: 0.5113 - val_loss: 1.4628 - val_accuracy: 0.4804
# Epoch 14/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.3337 - accuracy: 0.5222 - val_loss: 1.4398 - val_accuracy: 0.4934
# Epoch 15/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.3195 - accuracy: 0.5265 - val_loss: 1.4418 - val_accuracy: 0.4885
# Epoch 16/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.3048 - accuracy: 0.5325 - val_loss: 1.4788 - val_accuracy: 0.4859
# Epoch 17/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.2833 - accuracy: 0.5389 - val_loss: 1.4259 - val_accuracy: 0.4958
# Epoch 18/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.2711 - accuracy: 0.5420 - val_loss: 1.4566 - val_accuracy: 0.4950
# Epoch 19/20
# 196/196 [==============================] - 5s 25ms/step - loss: 1.2484 - accuracy: 0.5516 - val_loss: 1.4621 - val_accuracy: 0.4963
# Epoch 20/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.2268 - accuracy: 0.5580 - val_loss: 1.4356 - val_accuracy: 0.5022
# Experiment with LR = 0.010000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 5s 26ms/step - loss: 1.9226 - accuracy: 0.3132 - val_loss: 1.7828 - val_accuracy: 0.3746
# Epoch 2/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.7163 - accuracy: 0.3932 - val_loss: 1.6580 - val_accuracy: 0.4138
# Epoch 3/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.6300 - accuracy: 0.4228 - val_loss: 1.6353 - val_accuracy: 0.4182
# Epoch 4/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.5660 - accuracy: 0.4477 - val_loss: 1.5440 - val_accuracy: 0.4449
# Epoch 5/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.5206 - accuracy: 0.4642 - val_loss: 1.5127 - val_accuracy: 0.4630
# Epoch 6/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.4761 - accuracy: 0.4772 - val_loss: 1.4961 - val_accuracy: 0.4658
# Epoch 7/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.4428 - accuracy: 0.4867 - val_loss: 1.4518 - val_accuracy: 0.4823
# Epoch 8/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.4132 - accuracy: 0.4990 - val_loss: 1.4360 - val_accuracy: 0.4920
# Epoch 9/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.3827 - accuracy: 0.5104 - val_loss: 1.4173 - val_accuracy: 0.4919
# Epoch 10/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.3545 - accuracy: 0.5204 - val_loss: 1.4276 - val_accuracy: 0.4894
# Epoch 11/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.3337 - accuracy: 0.5296 - val_loss: 1.4124 - val_accuracy: 0.4941
# Epoch 12/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.3114 - accuracy: 0.5358 - val_loss: 1.3894 - val_accuracy: 0.5071
# Epoch 13/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.2937 - accuracy: 0.5404 - val_loss: 1.4600 - val_accuracy: 0.4849
# Epoch 14/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.2661 - accuracy: 0.5508 - val_loss: 1.4448 - val_accuracy: 0.4890
# Epoch 15/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.2448 - accuracy: 0.5613 - val_loss: 1.4475 - val_accuracy: 0.4954
# Epoch 16/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.2295 - accuracy: 0.5642 - val_loss: 1.4129 - val_accuracy: 0.4938
# Epoch 17/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.2117 - accuracy: 0.5722 - val_loss: 1.3525 - val_accuracy: 0.5167
# Epoch 18/20
# 196/196 [==============================] - 5s 23ms/step - loss: 1.1920 - accuracy: 0.5785 - val_loss: 1.3616 - val_accuracy: 0.5152
# Epoch 19/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.1706 - accuracy: 0.5848 - val_loss: 1.3662 - val_accuracy: 0.5203: 1.1694 - ac
# Epoch 20/20
# 196/196 [==============================] - 5s 24ms/step - loss: 1.1616 - accuracy: 0.5882 - val_loss: 1.3606 - val_accuracy: 0.5250

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

"""
將實驗結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
Adam

# %%
results = {}
"""
建立你的訓練與實驗迴圈並蒐集資料
"""
for lr in LEARNING_RATE:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with LR = %.6f" % (lr))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.Adam(lr=lr, epsilon=None, decay=0.0)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-lr-%s" % str(lr)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with LR = 1.000000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2634031.7500 - accuracy: 0.0981 - val_loss: 2.3251 - val_accuracy: 0.1000
# Epoch 2/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3182 - accuracy: 0.0999 - val_loss: 2.3272 - val_accuracy: 0.1000
# Epoch 3/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3223 - accuracy: 0.0993 - val_loss: 2.3247 - val_accuracy: 0.1000
# Epoch 4/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3215 - accuracy: 0.1004 - val_loss: 2.3171 - val_accuracy: 0.1000
# Epoch 5/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3236 - accuracy: 0.1004 - val_loss: 2.3168 - val_accuracy: 0.1000
# Epoch 6/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3235 - accuracy: 0.0984 - val_loss: 2.3349 - val_accuracy: 0.1000
# Epoch 7/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3304 - accuracy: 0.1005 - val_loss: 2.3182 - val_accuracy: 0.1000
# Epoch 8/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3319 - accuracy: 0.1012 - val_loss: 2.3195 - val_accuracy: 0.1000
# Epoch 9/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3286 - accuracy: 0.1000 - val_loss: 2.3510 - val_accuracy: 0.1000
# Epoch 10/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3315 - accuracy: 0.0984 - val_loss: 2.3239 - val_accuracy: 0.1000
# Epoch 11/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3396 - accuracy: 0.1005 - val_loss: 2.3469 - val_accuracy: 0.1000
# Epoch 12/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3321 - accuracy: 0.1005 - val_loss: 2.3298 - val_accuracy: 0.1000
# Epoch 13/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3330 - accuracy: 0.0973 - val_loss: 2.3298 - val_accuracy: 0.1000
# Epoch 14/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3359 - accuracy: 0.1008 - val_loss: 2.3453 - val_accuracy: 0.1000
# Epoch 15/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3341 - accuracy: 0.0980 - val_loss: 2.3461 - val_accuracy: 0.1000
# Epoch 16/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3309 - accuracy: 0.0992 - val_loss: 2.3275 - val_accuracy: 0.1000
# Epoch 17/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3295 - accuracy: 0.1006 - val_loss: 2.3217 - val_accuracy: 0.1000
# Epoch 18/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3315 - accuracy: 0.0997 - val_loss: 2.3381 - val_accuracy: 0.1000
# Epoch 19/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3324 - accuracy: 0.1002 - val_loss: 2.3461 - val_accuracy: 0.1000
# Epoch 20/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3348 - accuracy: 0.1020 - val_loss: 2.3554 - val_accuracy: 0.1000
# Experiment with LR = 0.100000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 3s 15ms/step - loss: 198.1682 - accuracy: 0.0963 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 2/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3039 - accuracy: 0.0996 - val_loss: 2.3043 - val_accuracy: 0.1000
# Epoch 3/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3046 - accuracy: 0.0988 - val_loss: 2.3058 - val_accuracy: 0.1000
# Epoch 4/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3045 - accuracy: 0.1013 - val_loss: 2.3059 - val_accuracy: 0.1000
# Epoch 5/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3049 - accuracy: 0.0984 - val_loss: 2.3046 - val_accuracy: 0.1000
# Epoch 6/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3051 - accuracy: 0.1009 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 7/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3053 - accuracy: 0.0985 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 8/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3057 - accuracy: 0.0996 - val_loss: 2.3046 - val_accuracy: 0.1000
# Epoch 9/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3054 - accuracy: 0.0990 - val_loss: 2.3088 - val_accuracy: 0.1000
# Epoch 10/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3068 - accuracy: 0.0972 - val_loss: 2.3071 - val_accuracy: 0.1000
# Epoch 11/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3066 - accuracy: 0.0994 - val_loss: 2.3047 - val_accuracy: 0.1000
# Epoch 12/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3064 - accuracy: 0.1003 - val_loss: 2.3078 - val_accuracy: 0.1000
# Epoch 13/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3063 - accuracy: 0.0990 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 14/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3069 - accuracy: 0.1002 - val_loss: 2.3060 - val_accuracy: 0.1000
# Epoch 15/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3062 - accuracy: 0.0993 - val_loss: 2.3054 - val_accuracy: 0.1000
# Epoch 16/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3056 - accuracy: 0.1011 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 17/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3060 - accuracy: 0.1007 - val_loss: 2.3065 - val_accuracy: 0.1000
# Epoch 18/20
# 196/196 [==============================] - 3s 14ms/step - loss: 2.3074 - accuracy: 0.0997 - val_loss: 2.3096 - val_accuracy: 0.1000
# Epoch 19/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3069 - accuracy: 0.1007 - val_loss: 2.3093 - val_accuracy: 0.1000
# Epoch 20/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.3076 - accuracy: 0.0994 - val_loss: 2.3083 - val_accuracy: 0.1000
# Experiment with LR = 0.010000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 3s 15ms/step - loss: 2.9965 - accuracy: 0.2509 - val_loss: 1.8516 - val_accuracy: 0.3150
# Epoch 2/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.7975 - accuracy: 0.3468 - val_loss: 1.7355 - val_accuracy: 0.3695
# Epoch 3/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.7443 - accuracy: 0.3681 - val_loss: 1.6993 - val_accuracy: 0.3786
# Epoch 4/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.6977 - accuracy: 0.3873 - val_loss: 1.6627 - val_accuracy: 0.4042
# Epoch 5/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.6924 - accuracy: 0.3896 - val_loss: 1.6881 - val_accuracy: 0.3991
# Epoch 6/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.6558 - accuracy: 0.4039 - val_loss: 1.6569 - val_accuracy: 0.3949
# Epoch 7/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.6206 - accuracy: 0.4171 - val_loss: 1.5830 - val_accuracy: 0.4307
# Epoch 8/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.6030 - accuracy: 0.4215 - val_loss: 1.6386 - val_accuracy: 0.4109
# Epoch 9/20
# 196/196 [==============================] - 3s 15ms/step - loss: 1.5946 - accuracy: 0.4269 - val_loss: 1.6143 - val_accuracy: 0.4154
# Epoch 10/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5769 - accuracy: 0.4323 - val_loss: 1.5905 - val_accuracy: 0.4276
# Epoch 11/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5721 - accuracy: 0.4352 - val_loss: 1.6281 - val_accuracy: 0.4156
# Epoch 12/20
# 196/196 [==============================] - 3s 15ms/step - loss: 1.5684 - accuracy: 0.4340 - val_loss: 1.6288 - val_accuracy: 0.4157
# Epoch 13/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5539 - accuracy: 0.4418 - val_loss: 1.5977 - val_accuracy: 0.4257
# Epoch 14/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5438 - accuracy: 0.4468 - val_loss: 1.6265 - val_accuracy: 0.4105
# Epoch 15/20
# 196/196 [==============================] - 3s 15ms/step - loss: 1.5486 - accuracy: 0.4422 - val_loss: 1.6734 - val_accuracy: 0.4029
# Epoch 16/20
# 196/196 [==============================] - 3s 15ms/step - loss: 1.5391 - accuracy: 0.4476 - val_loss: 1.5922 - val_accuracy: 0.4291
# Epoch 17/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5293 - accuracy: 0.4527 - val_loss: 1.5632 - val_accuracy: 0.4372
# Epoch 18/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5253 - accuracy: 0.4531 - val_loss: 1.5992 - val_accuracy: 0.4245
# Epoch 19/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5386 - accuracy: 0.4467 - val_loss: 1.6104 - val_accuracy: 0.4230
# Epoch 20/20
# 196/196 [==============================] - 3s 14ms/step - loss: 1.5269 - accuracy: 0.4507 - val_loss: 1.6491 - val_accuracy: 0.4150

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
